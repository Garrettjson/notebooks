# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Intro

# %% [markdown]
# Read in & display the image

# %% [markdown]
# We want to split the image into its main color groups that are most commonly seen in the image. We can show an example of this grouping with cv2

# %%
img = cv2.imread('../local_files/colors.jpeg')

#convert from BGR to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
#get rgb values from image to 1D array
r, g, b = cv2.split(img)
r = r.flatten()
g = g.flatten()
b = b.flatten()

def rgb_to_hex(r, g, b):
    return '#%02x%02x%02x' % (int(r), int(g), int(b))

#plotting 
fig = plt.figure()
ax = Axes3D(fig)
for x in range(len(r)):
    ax.scatter(r[x], g[x], b[x], c=rgb_to_hex(r[x], g[x], b[x]))
plt.show()

# free memory
del r,g,b

# %% [markdown]
# ### Getting Started

# %%
# read in & show image
img = cv2.imread('../local_files/boxes.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img, interpolation='nearest')

# %%
def kmeans_img(clust):
    # reshape to array of pixel color values
    X = img.reshape((-1,3))

    # convert to np.float32
    X = np.float32(X)

    # cluster data using kmeans
    kmeans = KMeans(n_clusters=clust).fit(X)

    # get labels & values of centerpoints
    # convert centers to unit8
    # unsigned 8bit --> max of 255
    centers = kmeans.cluster_centers_
    centers = np.uint8(centers)
    labels = kmeans.labels_

    res = centers[labels.flatten()]
    return res.reshape((img.shape))

# %%
# set number of colors (clusters)
clust = 5
img_by_clust = [] # maybe just display them as they're genereated instead of storeing them all

for x in range(1, clust):
    img_by_clust.append(kmeans_img(clust))

# %%
plt.imshow(res2, interpolation='nearest')
